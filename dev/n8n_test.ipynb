# %%
import requests

# %%
url = "http://localhost:5678/webhook-test/n8n-trigger"
payload = {
    "action": "update", 
    "workflow_id": "272i4kjkXwZzraHR", 
    "workflow_key_words": "LINE", 
    "workflow_object": { "name": "My workflow 123", "nodes": [], "connections": {}, "settings": {} }
}
response = requests.post(url, json=payload)
print(response.status_code)
# Out:
# 200

# %%
response.json()
# Out:
# {'updatedAt': '2026-01-26T13:27:46.009Z',
#  'createdAt': '2026-01-26T13:25:41.797Z',
#  'id': '272i4kjkXwZzraHR',
#  'name': 'My workflow 123',
#  'description': None,
#  'active': False,
#  'isArchived': False,
#  'nodes': [],
#  'connections': {},
#  'settings': {'callerPolicy': 'workflowsFromSameOwner',
#   'availableInMCP': False},
#  'staticData': None,
#  'meta': None,
#  'pinData': None,
#  'versionId': '048fb4bb-3064-4d4d-ae0d-a1fccb12a972',
#  'activeVersionId': None,
#  'versionCounter': 2,
#  'triggerCount': 0,
#  'tags': [],
#  'activeVersion': None}
